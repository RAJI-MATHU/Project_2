# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cus = pd.read_csv('Customers.csv',encoding='ISO-8859-1',parse_dates=['Birthday'])
pro=pd.read_csv('Products.csv')
sales=pd.read_csv('Sales.csv',parse_dates=['Order Date','Delivery Date'])
store = pd.read_csv('Stores.csv',parse_dates=['Open Date'])
exc=pd.read_csv('Exchange_Rates.csv',parse_dates=['Date'])

# %%
cus.head(2)
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State Zip Code    Country  Continent   Birthday
# 0    South Australia     5523  Australia  Australia 1939-07-03
# 1  Western Australia     6522  Australia  Australia 1979-09-27

# %%
cus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
cus.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
cus.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
k=cus.isnull().any(axis=1)
cus[k]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent   Birthday
# 5304  Napoli    80035   Italy    Europe 1981-04-18
# ...

# %%
cus.fillna('NAPO',inplace=True)

# %%
cus.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
cus
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
#cus['Birthday']=pd.to_datetime(cus['Birthday'],errors='coerce').dt.strftime('%d-%b-%Y')
#cus['Birthday']

# %%
pro.head(3)
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio

# %%
pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
pro.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
pro.isnull().any()
# Out:
# ProductKey        False
# Product Name      False
# Brand             False
# Color             False
# Unit Cost USD     False
# Unit Price USD    False
# SubcategoryKey    False
# Subcategory       False
# CategoryKey       False
# Category          False
# dtype: bool

# %%
pro['Unit Cost USD']=pro['Unit Cost USD'].str.replace("$","",regex=False).str.replace(",","",regex=False)
pro['Unit Cost USD']=pd.to_numeric(pro['Unit Cost USD'])

pro['Unit Price USD']=pro['Unit Price USD'].str.replace("$","",regex=False).str.replace(",","",regex=False)
pro['Unit Price USD']=pd.to_numeric(pro['Unit Price USD'])

# %%
pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
pro
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
store.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0 2008-01-01
# 1         2  Australia            Northern Territory          665.0 2008-01-12
# 2         3  Australia               South Australia         2000.0 2012-01-07
# 3         4  Australia                      Tasmania         2000.0 2010-01-01
# 4         5  Australia                      Victoria         2000.0 2015-12-09

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.7+ KB

# %%
store.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
store.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
k=store.isnull().any(axis=1)
store[k]
# Out:
#     StoreKey Country   State  Square Meters  Open Date
# 66         0  Online  Online            NaN 2010-01-01

# %%
mean=store['Square Meters'].mean()
store.fillna(mean,inplace=True)

# %%
store.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
store
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory      595.00000
# 1          2      Australia            Northern Territory      665.00000
# 2          3      Australia               South Australia     2000.00000
# 3          4      Australia                      Tasmania     2000.00000
# 4          5      Australia                      Victoria     2000.00000
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah     2000.00000
# 63        64  United States                 Washington DC     1330.00000
# 64        65  United States                 West Virginia     1785.00000
# 65        66  United States                       Wyoming      840.00000
# 66         0         Online                        Online     1402.19697
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
#store['Country']=store['Country'].astype(str)
#store['State']=store['State'].astype(str)

# %%
sales.head(3)
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 4.3+ MB

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date    datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales['Delivery Date'].fillna('NA',inplace=True)

# %%
#sales['Currency Code']=sales['Currency Code'].astype(str)

# %%
sales.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date            object
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
sales.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
sales
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01                   NA       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20                   NA      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# ...

# %%
exc
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
Finaldata = pd.merge(cus, sales, on='CustomerKey', how='inner')
Finaldata.head(2)
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State Zip Code    Country  Continent   Birthday  Order Number  \
# 0    South Australia     5523  Australia  Australia 1939-07-03       1776007
# 1  Western Australia     6522  Australia  Australia 1979-09-27       1109001
#
#    Line Item Order Date        Delivery Date  StoreKey  ProductKey  Quantity  \
# 0          1 2019-11-11  2019-11-13 00:00:00         0          53         2
# 1          1 2018-01-13                   NA         6         443         4
#
#   Currency Code
# 0           AUD
# 1           AUD

# %%
Finaldata.shape
# Out:
# (62884, 18)

# %%
Finaldata = pd.merge(Finaldata,pro,on='ProductKey',how='inner')
Finaldata.head(2)
# Out:
#    CustomerKey  Gender           Name            City State Code  \
# 0          301  Female  Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female   Madison Hull      MOUNT BUDD         WA
#
#                State Zip Code    Country  Continent   Birthday  ...  \
# 0    South Australia     5523  Australia  Australia 1939-07-03  ...
# 1  Western Australia     6522  Australia  Australia 1979-09-27  ...
#
#    Currency Code                            Product Name  \
# 0            AUD  WWI 4GB Video Recording Pen X200 Black
# 1            AUD          WWI Desktop PC3.0 M0300 Silver
#
#                   Brand   Color  Unit Cost USD  Unit Price USD  \
# 0  Wide World Importers   Black          98.07           296.0
# 1  Wide World Importers  Silver         160.49           349.0
#
#    SubcategoryKey    Subcategory CategoryKey   Category
# 0             104  Recording Pen           1      Audio
# 1             303       Desktops           3  Computers
#
# ...

# %%
Finaldata=pd.merge(Finaldata,store,on=['StoreKey','Country','State'],how='inner')
Finaldata.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'Delivery Date', 'StoreKey', 'ProductKey',
#        'Quantity', 'Currency Code', 'Product Name', 'Brand', 'Color',
#        'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory',
#        'CategoryKey', 'Category', 'Square Meters', 'Open Date'],
#       dtype='object')

# %%
Finaldata.shape
# Out:
# (6181, 29)

# %%
Finaldata = pd.merge(Finaldata,exc,left_on=['Currency Code','Order Date'],right_on=['Currency','Date'],how='inner',indicator=True)

# %%
Finaldata.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday', 'Order Number',
#        'Line Item', 'Order Date', 'Delivery Date', 'StoreKey', 'ProductKey',
#        'Quantity', 'Currency Code', 'Product Name', 'Brand', 'Color',
#        'Unit Cost USD', 'Unit Price USD', 'SubcategoryKey', 'Subcategory',
#        'CategoryKey', 'Category', 'Square Meters', 'Open Date', 'Date',
#        'Currency', 'Exchange', '_merge'],
#       dtype='object')

# %%
Finaldata
# Out:
#       CustomerKey  Gender              Name                City State Code  \
# 0             325  Female      Madison Hull          MOUNT BUDD         WA
# 1             325  Female      Madison Hull          MOUNT BUDD         WA
# 2             325  Female      Madison Hull          MOUNT BUDD         WA
# 3             325  Female      Madison Hull          MOUNT BUDD         WA
# 4             325  Female      Madison Hull          MOUNT BUDD         WA
# ...           ...     ...               ...                 ...        ...
# 6176      2097018  Female  Thérèse Lapresse        Simpsonville         SC
# 6177      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 6178      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 6179      2098404  Female    Lenka Cadilová  Pump Station Three         AK
# 6180      2098404  Female    Lenka Cadilová  Pump Station Three         AK
#
# ...

# %%
Finaldata.dtypes
# Out:
# CustomerKey                int64
# Gender                    object
# Name                      object
# City                      object
# State Code                object
# State                     object
# Zip Code                  object
# Country                   object
# Continent                 object
# Birthday          datetime64[ns]
# Order Number               int64
# Line Item                  int64
# Order Date        datetime64[ns]
# Delivery Date             object
# StoreKey                   int64
# ProductKey                 int64
# Quantity                   int64
# Currency Code             object
# Product Name              object
# Brand                     object
# Color                     object
# Unit Cost USD            float64
# Unit Price USD           float64
# SubcategoryKey             int64
# Subcategory               object
# CategoryKey                int64
# Category                  object
# Square Meters            float64
# ...

# %%
Finaldata.isnull().sum()
# Out:
# CustomerKey       0
# Gender            0
# Name              0
# City              0
# State Code        0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Square Meters     0
# Open Date         0
# Date              0
# Currency          0
# Exchange          0
# _merge            0
# dtype: int64

# %%
#Finaldata.to_csv('Finaldata.csv')

# %%
overall=sales

# %%
overall=pd.merge(overall,cus,on='CustomerKey',how='inner')

# %%
overall.dropna(inplace=True)

# %%
overall
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01                   NA       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20                   NA      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
# ...

# %%
overall=pd.merge(overall,exc,left_on=['Order Date','Currency Code'],right_on=['Date','Currency'],how='inner')

# %%
overall=pd.merge(overall,pro,on='ProductKey',how='inner')

# %%
overall=pd.merge(overall,store,on=['StoreKey','Country','State'],how='inner')

# %%
overall
# Out:
#       Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0           366005          1 2016-01-01            NA       844003        33
# 1           367006          1 2016-01-02            NA       693285        18
# 2           367010          1 2016-01-02            NA      1322959        66
# 3           367010          2 2016-01-02            NA      1322959        66
# 4           369007          1 2016-01-04            NA       571622        20
# ...            ...        ...        ...           ...          ...       ...
# 6176       2243014          1 2021-02-20            NA      1453427        50
# 6177       2243014          2 2021-02-20            NA      1453427        50
# 6178       2243014          3 2021-02-20            NA      1453427        50
# 6179       2243021          1 2021-02-20            NA      1783631        55
# 6180       2243021          2 2021-02-20            NA      1783631        55
#
# ...

# %%
#overall.to_csv('overall.csv')

# %%
#pip install mysql-connector-python pandas sqlalchemy

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    port = "3306",
    password="SQLraven#2024",
    autocommit=True,
    use_pure=True 
)
cursor = conn.cursor()

# Create a new database (if you don't have one yet)
cursor.execute("CREATE DATABASE IF NOT EXISTS dataspark")
cursor.execute("USE dataspark")

print("Connected to MySQL and database created!")
# Out:
# Connected to MySQL and database created!

# %%
host="localhost"
user="root"
port = "3306"
password="SQLraven#2024"
database="dataspark"

eng_str= f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}"
engine = create_engine(eng_str)

# %%
Finaldata.to_sql('final_all_table', con=engine, if_exists='replace', index=False)
print(f"successfully table imported to sql")
# Out:
# successfully table imported to sql

# %%
overall.to_sql('overall_table', con=engine, if_exists='replace', index=False)
print(f"successfully table imported to sql")
# Out:
# successfully table imported to sql

# %%
cus.to_sql('customer', con=engine, if_exists='replace', index=False)

pro.to_sql('products', con=engine, if_exists='replace', index=False)

sales.to_sql('sales', con=engine, if_exists='replace', index=False)

store.to_sql('stores', con=engine, if_exists='replace', index=False)

exc.to_sql('exchange_rate', con=engine, if_exists='replace', index=False)
# Out:
# 11215

# %%
cursor.close()
conn.close()
